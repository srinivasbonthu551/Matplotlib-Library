# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y = [23,4,55,66,34,56,67]

# %%
plt.plot(x,y,color='green',linewidth =5)
plt.xlabel("Day")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

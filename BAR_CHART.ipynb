# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
company = ["GOOGLE","AMAZON","FACEBOOK","INSTAGRAM"]
revenue = [90,136,89,27]

# %%
plt.bar(company,revenue)
plt.ylabel("Revenue(in MILLIONS)")
plt.xlabel("Company")
# Out:
# Text(0.5, 0, 'Company')
